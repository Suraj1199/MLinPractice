# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.set_printoptions(precision=4, threshold=20)

# %% [markdown]
# ### Load Data

# %%
boston_housing_full = pd.read_csv('Sklearn/downloaded_datasets/boston_housing/train.csv', index_col='ID')

# %%
boston_housing_full.head()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# ID
# 0    0.44178  0.0   6.20   0.0  0.504  6.552   21.4  3.3751   8.0  307.0
# 1    0.05372  0.0  13.92   0.0  0.437  6.549   51.0  5.9604   4.0  289.0
# 2   15.86030  0.0  18.10   0.0  0.679  5.896   95.4  1.9096  24.0  666.0
# 3    0.10574  0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 4   73.53410  0.0  18.10   0.0  0.679  5.957  100.0  1.8026  24.0  666.0
#
#     PTRATIO       B  LSTAT  MEDV
# ID
# 0      17.4  380.34   3.76  31.5
# 1      16.0  392.85   7.39  27.1
# 2      20.2    7.68  24.39   8.3
# 3      20.1  390.11  18.07  13.6
# 4      20.2   16.45  20.62   8.8

# %% [markdown]
# ### Explore Data

# %%
boston_housing_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    float64
#  4   NOX      404 non-null    float64
#  5   RM       404 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    float64
#  9   TAX      404 non-null    float64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  MEDV     404 non-null    float64
# dtypes: float64(14)
# memory usage: 47.3 KB

# %%
boston_housing_full.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.397354   11.456683   10.907426    0.074257    0.549308    6.296839
# std      8.947346   23.307205    6.788322    0.262514    0.112797    0.697770
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082382    0.000000    5.175000    0.000000    0.449000    5.878750
# 50%      0.247510    0.000000    8.560000    0.000000    0.532000    6.211500
# 75%      2.340397   14.375000   18.100000    0.000000    0.624000    6.626250
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.079703    3.808298    9.076733  398.717822   18.431683  361.763762
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(boston_housing_full.corr(), annot=True, )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Select Features and Target

# %%
features = ['INDUS', 'AGE', 'DIS', 'ZN', 'RAD', 'TAX', 'NOX', 'LSTAT']
X = boston_housing_full[features]
X.head()
# Out:
#     INDUS    AGE     DIS   ZN   RAD    TAX    NOX  LSTAT
# ID
# 0    6.20   21.4  3.3751  0.0   8.0  307.0  0.504   3.76
# 1   13.92   51.0  5.9604  0.0   4.0  289.0  0.437   7.39
# 2   18.10   95.4  1.9096  0.0  24.0  666.0  0.679  24.39
# 3   27.74   98.8  1.8681  0.0   4.0  711.0  0.609  18.07
# 4   18.10  100.0  1.8026  0.0  24.0  666.0  0.679  20.62

# %%
y = boston_housing_full['MEDV']
y.head()
# Out:
# ID
# 0    31.5
# 1    27.1
# 2     8.3
# 3    13.6
# 4     8.8
# Name: MEDV, dtype: float64
